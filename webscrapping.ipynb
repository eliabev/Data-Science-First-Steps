# %% [markdown]
# # Web Scrapping
#
# Coletar dados automaticamente, sem a intermediação de uma API. Um scrapping é capaz de consultar um servidor web, solicitar dados, analisar e extrair informações necessárias.
# Geralmente é usada quando não temos outras maneiras de extrair os dados. Geralmente os BD públicos não estão disponíveis, mas os dados ficam disponíveis em endpoints.
# ***Cuidado com a LGPD***!
#
# **BeuatifulSoup**: uma das mais utilizadas em Python para fazer web scrapping. Constroi uma árvore a partir de vários elementos de uma página e fornece uma interface simples para acessá-los.

# %% [markdown]
# ## Demonstração

# %%
import requests
from bs4 import BeautifulSoup as bsoup
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/eliabe/Dev/Data-Science/webscrapping.ipynb Cell 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/eliabe/Dev/Data-Science/webscrapping.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> from bs4 import BeautifulSoup as bsoup
#       <a href='vscode-notebook-cell:/home/eliabe/Dev/Data-Science/webscrapping.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/home/eliabe/Dev/Data-Science/webscrapping.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> import html5lib
#
# ModuleNotFoundError: No module named 'html5lib'

# %%
# https://statisticstimes.com/tech/top-computer-languages.php
html = requests.get('https://statisticstimes.com/tech/top-computer-languages.php').content
soup = bsoup(html, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
# <!--
# if (screen.width <= 699) {
# document.location = "https://m.statisticstimes.com/tech/top-computer-languages.php";
# }
# //-->
# </script>
# <title>Top Computer Languages 2022 - StatisticsTimes.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Top programming language in Jun 2022 in TIOBE Index and PYPL Index. Most
# most searched language in US, India, United Kingdom, France and Germany." name="description"/>
# <link href="https://m.statisticstimes.com/tech/top-computer-languages.php" media="only screen and (max-width: 699px)" rel="alternate"/>
# <link href="https://statisticstimes.com/tech/top-computer-languages.php" rel="canonical"/>
# <link href="../table.css" rel="stylesheet" type="text/css"/>
# <link href="../css_new.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="../DataTables-1.10.4/media/css/jquery.dataTables.css" rel="stylesheet" type="text/css"/>
# <script src="../DataTables-1.10.4/media/js/jquery.js"></script>
# <script src="../DataTables-1.10.4/media/js/jquery.dataTables.js"></script>
# <script>
# $(document).ready( function () {
#     $('#table_id').DataTable();
# } );
# $(document).ready( function () {
#     $('#table_id1').DataTable();
# } );
# $(document).ready( function () {
#     $('#table_id2').DataTable();
# } );
# $(document).ready( function () {
#     $('#table_id3').DataTable();
# } );
# $(document).ready( function () {
#     $('#table_id4').DataTable();
# } );
# $(document).ready( function () {
#     $('#table_id5').DataTable();
# } );
# $(document).ready( function () {
#     $('#table_id6').DataTable();
# } );
#
# $.extend( $.fn.dataTable.defaults, {
#     paging: false,
#     "info": false,
#     searching: false
# } );
# </script>
# <style>
# p,caption{
#   font-family: Arial, Helvetica, sans-serif;
# }
# #chartdiv {
#   width: 700px;
#   height: 600px;
# }
# </style>
# <script async="" defer="" src="//services.bilsyndication.com/adv1/?d=1604"></script><script> var vitag = vitag || {};</script>
# </head>
# <body>
# <div id="header">
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css">
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
# <script>
# window.addEventListener("load", function(){
# window.cookieconsent.initialise({
#   "palette": {
#     "popup": {
#       "background": "#000"
#     },
#     "button": {
#       "background": "#f1d600"
#     }
#   },
#   "content": {
#     "message": "This site uses cookies to analyse traffic and for ads measurement purposes.",
#     "href": "/privacy.php"
#   }
# })});
# </script>
# <div id="top" style="background-color:#4d94ff; width:1150px;height: 100px;">
# <div style="margin-left:50px;float: left; padding-top:5px; width:200px;height:90px;">
# <a href="/index.php">
# <img alt="statisticstimes" height="90" src="/statistics.png" width="200"/>
# </a>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-57003708-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <div class="navbar">
# <div class="dropdown">
# <button class="dropbtn">Home
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/index.php">World</a>
# <a href="/india.php">India</a>
# </div>
# </div>
# <div class="dropdown">
# <button class="dropbtn">Economy
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/economy/world-statistics.php">World</a>
# <a href="/economy/country-statistics.php">Country</a>
# <a href="/economy/india-statistics.php">India</a>
# </div>
# </div>
# <div class="dropdown">
# <button class="dropbtn">Demographics
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/demographics/world-statistics.php">World</a>
# <a href="/demographics/country-statistics.php">Country</a>
# <a href="/demographics/india-statistics.php">India</a>
# </div>
# </div>
# <a href="/health/coronavirus-statistics.php">Coronavirus</a>
# <div class="dropdown">
# <button class="dropbtn">Politics
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/politics/india-statistics.php">India</a>
# </div>
# </div>
# <div class="dropdown">
# <button class="dropbtn">Geography
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/geography/world-statistics.php">World</a>
# <a href="/geography/india-statistics.php">India</a>
# </div>
# </div>
# <a href="/tech/world-statistics.php">Tech</a>
# <div class="dropdown">
# <button class="dropbtn">Sports
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/sports/world-statistics.php">World</a>
# <a href="/sports/india-statistics.php">India</a>
# </div>
# </div>
# <a href="/ranking/world-statistics.php">Ranking</a>
# <div class="dropdown">
# <button class="dropbtn">Article
#       <i class="fa fa-caret-down"></i>
# </button>
# <div class="dropdown-content">
# <a href="/article/world-statistics.php">World</a>
# <a href="/article/india-statistics.php">India</a>
# </div>
# </div>
# </div>
# </div>
# <div id="main" itemscope="" itemtype="https://schema.org/WebPageElement">
# <div class="fwidth">
# <h1 itemprop="about">Top Computer Languages</h1>
# <table class="reference">
# <tr><td rowspan="2">Source</td>
# <td><a href="https://www.tiobe.com/tiobe-index/" target="_blank">TIOBE Index</a></td></tr>
# <tr><td><a href="http://pypl.github.io/PYPL.html" target="_blank">PYPL PopularitY of Programming Language Index</a></td></tr>
# <tr><td>Last Updated</td><td>27 Jun 2022</td></tr>
# </table>
# </div>
# <div class="right">
# <div class="content-separator"></div>
# <div class="space">
# <div class="adsbyvli" data-ad-slot="vi_16043977"></div> <script>(vitag.Init = window.vitag.Init || []).push(function () { viAPItag.display("vi_16043977") })</script></div>
# <div class="content-separator"></div>
# <div class="space latest border">
# <div style="text-align:center;float:left;margin-left:10px;font-size:20px;padding-top:10px;padding-bottom:5px;width:330px;">
#     Top Statistics
# </div>
# <div style="float:left;margin-left:10px;padding-top:5px;padding-bottom:5px;width:325px;border-bottom:1px solid #993366; ">
# <a class="ls" href="/sports/olympics/olympics-medal-table.php">
#        Olympics Medal Table 2020</a>
# </div>
# <div style="float:left;margin-left:10px;padding-top:5px;padding-bottom:5px;width:325px;border-bottom:1px solid #993366; ">
# <a class="ls" href="/economy/continents-by-gdp-per-capita.php">
#        List of continents by gdp per capita</a>
# </div>
# <div style="float:left;margin-left:10px;padding-top:5px;padding-bottom:5px;width:325px;border-bottom:1px solid #993366; ">
# <a class="ls" href="/demographics/world-urban-population.php">
#        World urban population</a>
# </div></div>
# </div>
# <div class="divpara para">
# <div class="para">
# <p>Python is the top programming language in TIOBE and PYPL Index. C closely follow Top-ranked Python in TIOBE.
# In PYPL, a gap is wider as top-ranked Python has taken a lead of close to 10% from 2nd ranked Java.</p>
# <p><b>TIOBE:</b> Python, C, Java and C++ are way ahead of others in TIOBE Index. C++ is about to surpass Java.
# C# and Visual Basic are very close to each other at 5th and 6th number. These four have negative
# trends in the past five years: Java, C, C#, and PHP. PHP was at 3rd position in Mar 2010 is now at 13th.
# Positions of Java and C have not been much affected, but their ratings are constantly declining. The rating
# of Java has declined from 26.49% in June 2001 to 10.47% in Jun 2022.</p>
# <p><b>PYPL:</b> Acc to PYPL, which publishes separate ranking for five countries, Python is the top language in all five countries
# (US, India, Germany, United Kingdom, France). Python has taken a huge lead in these five countries over the 2nd number
# of Java, and its shares are even almost double of Java in fourFrance, United Kingdom and Germany. These two account for almost
# half (45%) of the global search. JavaScript has attained its all time highest share of 9.5% in Sep 2021. JavaScript is at 3rd
# position in US, India and United Kingdom and within top five in all five countries.</p>
# <p>PHP is the biggest loser in recent years in PYPL. Its share was over 20% in 2008; now, this fig is only 5.27% in 2022.
# Java is too declining but not as fast as PHP. Java's contribution was over 31% in 2008, and still, it holds 18%. In
# 2004-2009, 50% of the search was of either Java or PHP.</p>
# <p><b>TIOBE Index:</b> TIOBE ratings are calculated by counting hits of the most popular search engines. Twenty-five
# search engines are used to calculate the TIOBE index. The TIOBE Programming Community index is an indicator of the
#  popularity of programming languages. The index started in the year 2001 and updated once a month.</p>
# <p><b>PYPL Index:</b> The PYPL PopularitY of Programming Language Index is created by analyzing how often language
#  tutorials are searched on Google. The index is updated once a month.</p>
# <!--C is the most widely popular programming language in TIOBE Index, while Python is the most searched language
# in PYPL Index. Python has the highest share in US, 29.69%, and the lowest 31% in India. -->
# </div>
# <div class="native">
# <div class="content-separator"></div>
# <div class="adsbyvli" data-ad-slot="vi_16043978"></div> <script>(vitag.Init = window.vitag.Init || []).push(function () { viAPItag.display("vi_16043978") })</script><div class="content-separator"></div>
# </div>
# </div>
# <div class="fwidth">
# <div class="border" id="chartdiv"></div>
# </div>
# <div style="float:left;width:1150px;margin-top:20px;">
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:530px;padding-bottom:10px;">
# <table class="display" id="table_id" style="width:525px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">TIOBE Index</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Jun 2021</th><th>Change</th>
# <th>Programming language</th><th>Ratings</th><th>Change</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="data1">2</td><td class="data1">↑</td><td class="name">Python</td><td class="data1">12.20%</td><td class="data1">+0.35%</td></tr>
# <tr><td class="data1">2</td><td class="data1">1</td><td class="data1">↓</td><td class="name">C</td><td class="data1">11.91%</td><td class="data1">-0.64%</td></tr>
# <tr><td class="data1">3</td><td class="data1">3</td><td class="data1"></td><td class="name">Java</td><td class="data1">10.47%</td><td class="data1">-1.07%</td></tr>
# <tr><td class="data1">4</td><td class="data1">4</td><td class="data1"></td><td class="name">C++</td><td class="data1">9.63%</td><td class="data1">+2.26%</td></tr>
# <tr><td class="data1">5</td><td class="data1">5</td><td class="data1"></td><td class="name">C#</td><td class="data1">6.12%</td><td class="data1">+1.79%</td></tr>
# <tr><td class="data1">6</td><td class="data1">6</td><td class="data1"></td><td class="name">Visual Basic</td><td class="data1">5.42%</td><td class="data1">+1.40%</td></tr>
# <tr><td class="data1">7</td><td class="data1">7</td><td class="data1"></td><td class="name">JavaScript</td><td class="data1">2.09%</td><td class="data1">-0.24%</td></tr>
# <tr><td class="data1">8</td><td class="data1">10</td><td class="data1">↑</td><td class="name">SQL</td><td class="data1">1.94%</td><td class="data1">+0.06%</td></tr>
# <tr><td class="data1">9</td><td class="data1">9</td><td class="data1"></td><td class="name">Assembly language</td><td class="data1">1.85%</td><td class="data1">-0.21%</td></tr>
# <tr><td class="data1">10</td><td class="data1">16</td><td class="data1">↑↑</td><td class="name">Swift</td><td class="data1">1.55%</td><td class="data1">+0.44%</td></tr>
# <tr><td class="data1">11</td><td class="data1">11</td><td class="data1"></td><td class="name">Classic Visual Basic</td><td class="data1">1.33%</td><td class="data1">-0.40%</td></tr>
# <tr><td class="data1">12</td><td class="data1">18</td><td class="data1">↑↑</td><td class="name">Delphi/Object Pascal</td><td class="data1">1.32%</td><td class="data1">+0.26%</td></tr>
# <tr><td class="data1">13</td><td class="data1">8</td><td class="data1">↓↓</td><td class="name">PHP</td><td class="data1">1.25%</td><td class="data1">-0.97%</td></tr>
# <tr><td class="data1">14</td><td class="data1">23</td><td class="data1">↑↑</td><td class="name">Objective-C</td><td class="data1">1.02%</td><td class="data1">+0.33%</td></tr>
# <tr><td class="data1">15</td><td class="data1">20</td><td class="data1">↑↑</td><td class="name">Go</td><td class="data1">1.02%</td><td class="data1">+0.07%</td></tr>
# <tr><td class="data1">16</td><td class="data1">14</td><td class="data1">↓</td><td class="name">R</td><td class="data1">0.98%</td><td class="data1">-0.22%</td></tr>
# <tr><td class="data1">17</td><td class="data1">15</td><td class="data1">↓</td><td class="name">Perl</td><td class="data1">0.76%</td><td class="data1">-0.41%</td></tr>
# <tr><td class="data1">18</td><td class="data1">38</td><td class="data1">↑↑</td><td class="name">Lua</td><td class="data1">0.76%</td><td class="data1">+0.43%</td></tr>
# <tr><td class="data1">19</td><td class="data1">13</td><td class="data1">↓↓</td><td class="name">Ruby</td><td class="data1">0.75%</td><td class="data1">-0.48%</td></tr>
# <tr><td class="data1">20</td><td class="data1">26</td><td class="data1">↑↑</td><td class="name">Prolog</td><td class="data1">0.74%</td><td class="data1">+0.18%</td></tr>
# </tbody>
# </table>
# </div>
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:450px;padding-bottom:10px;">
# <table class="display" id="table_id1" style="width:440px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">PYPL Index (Worldwide)</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Change</th><th>Programming language</th>
# <th>Share</th><th>Trends</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="data1"></td><td class="name">Python</td><td class="data1"> 27.61 %</td><td class="data1">-2.8 %</td></tr>
# <tr><td class="data1">2</td><td class="data1"></td><td class="name">Java</td><td class="data1"> 17.64 %</td><td class="data1">-0.7 %</td></tr>
# <tr><td class="data1">3</td><td class="data1"></td><td class="name">JavaScript</td><td class="data1"> 9.21 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">4</td><td class="data1"></td><td class="name">C#</td><td class="data1"> 7.79 %</td><td class="data1">+0.8 %</td></tr>
# <tr><td class="data1">5</td><td class="data1"></td><td class="name">C/C++</td><td class="data1"> 7.01 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">6</td><td class="data1"></td><td class="name">PHP</td><td class="data1"> 5.27 %</td><td class="data1">-1.0 %</td></tr>
# <tr><td class="data1">7</td><td class="data1"></td><td class="name">R</td><td class="data1"> 4.26 %</td><td class="data1">+0.5 %</td></tr>
# <tr><td class="data1">8</td><td class="data1">↑↑↑</td><td class="name">TypeScript</td><td class="data1"> 2.43 %</td><td class="data1">+0.7 %</td></tr>
# <tr><td class="data1">9</td><td class="data1">↓</td><td class="name">Objective-C</td><td class="data1"> 2.21 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">10</td><td class="data1">↓</td><td class="name">Swift</td><td class="data1"> 2.17 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">11</td><td class="data1">↑↑</td><td class="name">Matlab</td><td class="data1"> 1.71 %</td><td class="data1">+0.2 %</td></tr>
# <tr><td class="data1">12</td><td class="data1">↓↓</td><td class="name">Kotlin</td><td class="data1"> 1.57 %</td><td class="data1">-0.2 %</td></tr>
# <tr><td class="data1">13</td><td class="data1">↓</td><td class="name">Go</td><td class="data1"> 1.48 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">14</td><td class="data1">↑↑</td><td class="name">Rust</td><td class="data1"> 1.29 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">15</td><td class="data1"></td><td class="name">Ruby</td><td class="data1"> 1.1 %</td><td class="data1">-0.0 %</td></tr>
# <tr><td class="data1">16</td><td class="data1">↓↓</td><td class="name">VBA</td><td class="data1"> 1.07 %</td><td class="data1">-0.2 %</td></tr>
# <tr><td class="data1">17</td><td class="data1">↑↑</td><td class="name">Ada</td><td class="data1"> 0.95 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">18</td><td class="data1">↑↑↑</td><td class="name">Scala</td><td class="data1"> 0.73 %</td><td class="data1">+0.2 %</td></tr>
# <tr><td class="data1">19</td><td class="data1">↓↓</td><td class="name">Visual Basic</td><td class="data1"> 0.65 %</td><td class="data1">-0.0 %</td></tr>
# <tr><td class="data1">20</td><td class="data1">↓↓</td><td class="name">Dart</td><td class="data1"> 0.64 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">21</td><td class="data1">↑</td><td class="name">Abap</td><td class="data1"> 0.58 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">22</td><td class="data1">↓↓</td><td class="name">Lua</td><td class="data1"> 0.51 %</td><td class="data1">-0.0 %</td></tr>
# <tr><td class="data1">23</td><td class="data1">↑</td><td class="name">Groovy</td><td class="data1"> 0.48 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">24</td><td class="data1">↓</td><td class="name">Perl</td><td class="data1"> 0.44 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">25</td><td class="data1"></td><td class="name">Julia</td><td class="data1"> 0.41 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">26</td><td class="data1"></td><td class="name">Cobol</td><td class="data1"> 0.34 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">27</td><td class="data1"></td><td class="name">Haskell</td><td class="data1"> 0.29 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">28</td><td class="data1"></td><td class="name">Delphi/Pascal</td><td class="data1"> 0.16 %</td><td class="data1">+0.1 %</td></tr>
# </tbody>
# </table>
# </div>
# <div class="ad" style="float:right;width:160px;height:600px;">
# <div class="adsbyvli" data-ad-slot="vi_16043979"></div> <script>(vitag.Init = window.vitag.Init || []).push(function () { viAPItag.display("vi_16043979") })</script></div>
# </div>
# <div style="float:left;width:1150px;margin-top:20px;">
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:350px;padding-bottom:10px;">
# <table class="display" id="table_id2" style="width:340px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">PYPL Index (US)</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Programming language</th><th>Share</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="name">Python</td><td class="data1">29.53 %</td></tr><tr><td class="data1">2</td><td class="name">Java</td><td class="data1">17.06 %</td></tr><tr><td class="data1">3</td><td class="name">JavaScript</td><td class="data1">8.56 %</td></tr><tr><td class="data1">4</td><td class="name">C/C++</td><td class="data1">6.49 %</td></tr><tr><td class="data1">5</td><td class="name">C#</td><td class="data1">6.31 %</td></tr><tr><td class="data1">6</td><td class="name">R</td><td class="data1">5.83 %</td></tr><tr><td class="data1">7</td><td class="name">Objective-C</td><td class="data1">3.43 %</td></tr><tr><td class="data1">8</td><td class="name">Swift</td><td class="data1">2.89 %</td></tr><tr><td class="data1">9</td><td class="name">PHP</td><td class="data1">2.85 %</td></tr><tr><td class="data1">10</td><td class="name">Rust</td><td class="data1">2.33 %</td></tr><tr><td class="data1">11</td><td class="name">Ruby</td><td class="data1">2.25 %</td></tr><tr><td class="data1">12</td><td class="name">Matlab</td><td class="data1">2.06 %</td></tr><tr><td class="data1">13</td><td class="name">TypeScript</td><td class="data1">1.98 %</td></tr><tr><td class="data1">14</td><td class="name">Go</td><td class="data1">1.85 %</td></tr><tr><td class="data1">15</td><td class="name">VBA</td><td class="data1">1.11 %</td></tr><tr><td class="data1">16</td><td class="name">Scala</td><td class="data1">0.79 %</td></tr><tr><td class="data1">17</td><td class="name">Lua</td><td class="data1">0.79 %</td></tr><tr><td class="data1">18</td><td class="name">Julia</td><td class="data1">0.77 %</td></tr><tr><td class="data1">19</td><td class="name">Kotlin</td><td class="data1">0.7 %</td></tr><tr><td class="data1">20</td><td class="name">Visual Basic</td><td class="data1">0.59 %</td></tr><tr><td class="data1">21</td><td class="name">Perl</td><td class="data1">0.41 %</td></tr><tr><td class="data1">22</td><td class="name">Groovy</td><td class="data1">0.4 %</td></tr><tr><td class="data1">23</td><td class="name">Haskell</td><td class="data1">0.27 %</td></tr><tr><td class="data1">24</td><td class="name">Abap</td><td class="data1">0.24 %</td></tr><tr><td class="data1">25</td><td class="name">Cobol</td><td class="data1">0.23 %</td></tr><tr><td class="data1">26</td><td class="name">Ada</td><td class="data1">0.11 %</td></tr><tr><td class="data1">27</td><td class="name">Dart</td><td class="data1">0.11 %</td></tr><tr><td class="data1">28</td><td class="name">Delphi/Pascal</td><td class="data1">0.05 %</td></tr></tbody>
# </table>
# </div>
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:350px;padding-bottom:10px;">
# <table class="display" id="table_id3" style="width:340px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">PYPL Index (India)</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Programming language</th><th>Share</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="name">Python</td><td class="data1">26.5 %</td></tr><tr><td class="data1">2</td><td class="name">Java</td><td class="data1">22.96 %</td></tr><tr><td class="data1">3</td><td class="name">JavaScript</td><td class="data1">11.17 %</td></tr><tr><td class="data1">4</td><td class="name">C/C++</td><td class="data1">8.86 %</td></tr><tr><td class="data1">5</td><td class="name">C#</td><td class="data1">8.16 %</td></tr><tr><td class="data1">6</td><td class="name">PHP</td><td class="data1">5.66 %</td></tr><tr><td class="data1">7</td><td class="name">TypeScript</td><td class="data1">2.55 %</td></tr><tr><td class="data1">8</td><td class="name">R</td><td class="data1">2.51 %</td></tr><tr><td class="data1">9</td><td class="name">Kotlin</td><td class="data1">1.34 %</td></tr><tr><td class="data1">10</td><td class="name">Swift</td><td class="data1">1.19 %</td></tr><tr><td class="data1">11</td><td class="name">Objective-C</td><td class="data1">1.05 %</td></tr><tr><td class="data1">12</td><td class="name">Abap</td><td class="data1">1.02 %</td></tr><tr><td class="data1">13</td><td class="name">Go</td><td class="data1">0.94 %</td></tr><tr><td class="data1">14</td><td class="name">Scala</td><td class="data1">0.85 %</td></tr><tr><td class="data1">15</td><td class="name">Matlab</td><td class="data1">0.79 %</td></tr><tr><td class="data1">16</td><td class="name">Dart</td><td class="data1">0.72 %</td></tr><tr><td class="data1">17</td><td class="name">VBA</td><td class="data1">0.71 %</td></tr><tr><td class="data1">18</td><td class="name">Groovy</td><td class="data1">0.67 %</td></tr><tr><td class="data1">19</td><td class="name">Ruby</td><td class="data1">0.61 %</td></tr><tr><td class="data1">20</td><td class="name">Cobol</td><td class="data1">0.53 %</td></tr><tr><td class="data1">21</td><td class="name">Perl</td><td class="data1">0.51 %</td></tr><tr><td class="data1">22</td><td class="name">Visual Basic</td><td class="data1">0.35 %</td></tr><tr><td class="data1">23</td><td class="name">Rust</td><td class="data1">0.18 %</td></tr><tr><td class="data1">24</td><td class="name">Julia</td><td class="data1">0.07 %</td></tr><tr><td class="data1">25</td><td class="name">Ada</td><td class="data1">0.04 %</td></tr><tr><td class="data1">26</td><td class="name">Haskell</td><td class="data1">0.03 %</td></tr><tr><td class="data1">27</td><td class="name">Delphi/Pascal</td><td class="data1">0.03 %</td></tr></tbody>
# </table>
# </div>
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:350px;padding-bottom:10px;">
# <table class="display" id="table_id4" style="width:340px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">PYPL Index (Germany)</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Programming language</th><th>Share</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="name">Python</td><td class="data1">31.71 %</td></tr><tr><td class="data1">2</td><td class="name">Java</td><td class="data1">15.04 %</td></tr><tr><td class="data1">3</td><td class="name">C#</td><td class="data1">8.84 %</td></tr><tr><td class="data1">4</td><td class="name">JavaScript</td><td class="data1">6.6 %</td></tr><tr><td class="data1">5</td><td class="name">R</td><td class="data1">5.18 %</td></tr><tr><td class="data1">6</td><td class="name">C/C++</td><td class="data1">4.82 %</td></tr><tr><td class="data1">7</td><td class="name">PHP</td><td class="data1">3.92 %</td></tr><tr><td class="data1">8</td><td class="name">TypeScript</td><td class="data1">3.15 %</td></tr><tr><td class="data1">9</td><td class="name">Swift</td><td class="data1">2.4 %</td></tr><tr><td class="data1">10</td><td class="name">Rust</td><td class="data1">2.39 %</td></tr><tr><td class="data1">11</td><td class="name">Objective-C</td><td class="data1">2.35 %</td></tr><tr><td class="data1">12</td><td class="name">Matlab</td><td class="data1">2.25 %</td></tr><tr><td class="data1">13</td><td class="name">VBA</td><td class="data1">2.1 %</td></tr><tr><td class="data1">14</td><td class="name">Kotlin</td><td class="data1">1.44 %</td></tr><tr><td class="data1">15</td><td class="name">Go</td><td class="data1">1.26 %</td></tr><tr><td class="data1">16</td><td class="name">Abap</td><td class="data1">1.17 %</td></tr><tr><td class="data1">17</td><td class="name">Scala</td><td class="data1">0.87 %</td></tr><tr><td class="data1">18</td><td class="name">Delphi/Pascal</td><td class="data1">0.87 %</td></tr><tr><td class="data1">19</td><td class="name">Julia</td><td class="data1">0.75 %</td></tr><tr><td class="data1">20</td><td class="name">Ruby</td><td class="data1">0.75 %</td></tr><tr><td class="data1">21</td><td class="name">Haskell</td><td class="data1">0.55 %</td></tr><tr><td class="data1">22</td><td class="name">Lua</td><td class="data1">0.5 %</td></tr><tr><td class="data1">23</td><td class="name">Groovy</td><td class="data1">0.5 %</td></tr><tr><td class="data1">24</td><td class="name">Dart</td><td class="data1">0.37 %</td></tr><tr><td class="data1">25</td><td class="name">Perl</td><td class="data1">0.24 %</td></tr></tbody>
# </table>
# </div>
# </div>
# <div style="float:left;width:1150px;margin-top:20px;">
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:350px;padding-bottom:10px;">
# <table class="display" id="table_id5" style="width:340px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">PYPL Index (United Kingdom)</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Programming language</th><th>Share</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="name">Python</td><td class="data1">32.9 %</td></tr><tr><td class="data1">2</td><td class="name">Java</td><td class="data1">14.45 %</td></tr><tr><td class="data1">3</td><td class="name">JavaScript</td><td class="data1">10.1 %</td></tr><tr><td class="data1">4</td><td class="name">C#</td><td class="data1">7.9 %</td></tr><tr><td class="data1">5</td><td class="name">R</td><td class="data1">7.22 %</td></tr><tr><td class="data1">6</td><td class="name">C/C++</td><td class="data1">4.1 %</td></tr><tr><td class="data1">7</td><td class="name">PHP</td><td class="data1">3.1 %</td></tr><tr><td class="data1">8</td><td class="name">Rust</td><td class="data1">2.74 %</td></tr><tr><td class="data1">9</td><td class="name">Objective-C</td><td class="data1">2.68 %</td></tr><tr><td class="data1">10</td><td class="name">Matlab</td><td class="data1">2.05 %</td></tr><tr><td class="data1">11</td><td class="name">TypeScript</td><td class="data1">1.9 %</td></tr><tr><td class="data1">12</td><td class="name">Swift</td><td class="data1">1.74 %</td></tr><tr><td class="data1">13</td><td class="name">Go</td><td class="data1">1.5 %</td></tr><tr><td class="data1">14</td><td class="name">Kotlin</td><td class="data1">0.96 %</td></tr><tr><td class="data1">15</td><td class="name">VBA</td><td class="data1">0.95 %</td></tr><tr><td class="data1">16</td><td class="name">Scala</td><td class="data1">0.86 %</td></tr><tr><td class="data1">17</td><td class="name">Dart</td><td class="data1">0.85 %</td></tr><tr><td class="data1">18</td><td class="name">Haskell</td><td class="data1">0.73 %</td></tr><tr><td class="data1">19</td><td class="name">Perl</td><td class="data1">0.67 %</td></tr><tr><td class="data1">20</td><td class="name">Ruby</td><td class="data1">0.66 %</td></tr><tr><td class="data1">21</td><td class="name">Julia</td><td class="data1">0.62 %</td></tr><tr><td class="data1">22</td><td class="name">Lua</td><td class="data1">0.59 %</td></tr><tr><td class="data1">23</td><td class="name">Groovy</td><td class="data1">0.41 %</td></tr><tr><td class="data1">24</td><td class="name">Visual Basic</td><td class="data1">0.23 %</td></tr><tr><td class="data1">25</td><td class="name">Cobol</td><td class="data1">0.07 %</td></tr></tbody>
# </table>
# </div>
# <div itemprop="text" itemscope="" itemtype="http://schema.org/Table" style="float:left;width:350px;padding-bottom:10px;">
# <table class="display" id="table_id6" style="width:340px;display:table;border:1px solid #0000FF;">
# <caption style="caption-side:top">PYPL Index (France)</caption>
# <thead>
# <tr style="background-color:#0000FF"><th>Jun 2022</th><th>Programming language</th><th>Share</th></tr>
# </thead>
# <tbody>
# <tr><td class="data1">1</td><td class="name">Python</td><td class="data1">34.22 %</td></tr><tr><td class="data1">2</td><td class="name">Java</td><td class="data1">14.4 %</td></tr><tr><td class="data1">3</td><td class="name">C/C++</td><td class="data1">7.61 %</td></tr><tr><td class="data1">4</td><td class="name">R</td><td class="data1">7.22 %</td></tr><tr><td class="data1">5</td><td class="name">JavaScript</td><td class="data1">6.13 %</td></tr><tr><td class="data1">6</td><td class="name">C#</td><td class="data1">5.92 %</td></tr><tr><td class="data1">7</td><td class="name">PHP</td><td class="data1">4.77 %</td></tr><tr><td class="data1">8</td><td class="name">TypeScript</td><td class="data1">3.87 %</td></tr><tr><td class="data1">9</td><td class="name">Go</td><td class="data1">3.07 %</td></tr><tr><td class="data1">10</td><td class="name">Objective-C</td><td class="data1">2.42 %</td></tr><tr><td class="data1">11</td><td class="name">Rust</td><td class="data1">2.3 %</td></tr><tr><td class="data1">12</td><td class="name">Kotlin</td><td class="data1">2.02 %</td></tr><tr><td class="data1">13</td><td class="name">Matlab</td><td class="data1">1.38 %</td></tr><tr><td class="data1">14</td><td class="name">VBA</td><td class="data1">1.24 %</td></tr><tr><td class="data1">15</td><td class="name">Swift</td><td class="data1">0.98 %</td></tr><tr><td class="data1">16</td><td class="name">Scala</td><td class="data1">0.67 %</td></tr><tr><td class="data1">17</td><td class="name">Cobol</td><td class="data1">0.37 %</td></tr><tr><td class="data1">18</td><td class="name">Julia</td><td class="data1">0.3 %</td></tr><tr><td class="data1">19</td><td class="name">Dart</td><td class="data1">0.28 %</td></tr><tr><td class="data1">20</td><td class="name">Ruby</td><td class="data1">0.27 %</td></tr><tr><td class="data1">21</td><td class="name">Lua</td><td class="data1">0.26 %</td></tr><tr><td class="data1">22</td><td class="name">Visual Basic</td><td class="data1">0.15 %</td></tr><tr><td class="data1">23</td><td class="name">Perl</td><td class="data1">0.14 %</td></tr></tbody>
# </table>
# </div>
# <div class="ad" style="float:right;width:300px;height:600px;">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 300_600 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-7716747007138100" data-ad-slot="4221463570" style="display:inline-block;width:300px;height:600px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# </div>
# </div>
# <div id="footer" style="float:left;width:1150px;">
# <div style="width:100px;float:left;height:100px;">
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <div class="addthis_horizontal_follow_toolbox"></div>
# </div>
# <div style="width:1050px;float:left;height:100px;">
# <div style="width:700px;float:left;padding-left:300px;padding-top:20px;">
# <a href="/about.php" style="text-decoration: none;"> About US</a> |
#     <a href="/termsofuse.php" style="text-decoration: none;"> Terms Of Use </a> |
#     <a href="/privacy.php" style="text-decoration: none;"> Privacy Policy </a> |
#     <a href="/contact.php" style="text-decoration: none;"> Contact Us </a>
# </div>
# <div style="width:650px;float:left;padding-left:350px;padding-top:10px;">© 2021 - StatisticsTimes.com</div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54d4ab9b03845be6"></script></div>
# </link></div>
# <script src="https://www.amcharts.com/lib/4/core.js"></script>
# <script src="https://www.amcharts.com/lib/4/charts.js"></script>
# <script src="https://www.amcharts.com/lib/4/themes/animated.js"></script>
# <script>
# am4core.useTheme(am4themes_animated);
#
# // Create chart instance
# var chart = am4core.create("chartdiv", am4charts.XYChart);
#
# var title = chart.titles.create();
# title.text = "Top Computer Languages (Jun 2022)";
# title.fontSize = 20;
# title.marginBottom = 10;
#
# chart.dataSource.url = "../m/tech/json/computer-language.json";
# // Create axes
# var categoryAxis = chart.yAxes.push(new am4charts.CategoryAxis());
# categoryAxis.dataFields.category = "lang";
# categoryAxis.renderer.grid.template.location = 0;
# categoryAxis.renderer.grid.template.disabled = true;
# categoryAxis.renderer.cellStartLocation = 0.1;
# categoryAxis.renderer.cellEndLocation = 0.9;
# // categoryAxis.renderer.fontSize = 10;
# categoryAxis.renderer.inversed = true;
# categoryAxis.title.text = "Language";
# categoryAxis.cursorTooltipEnabled = false;
#
# var valueAxis = chart.xAxes.push(new am4charts.ValueAxis());
# valueAxis.title.text = "Share (%)";
# valueAxis.cursorTooltipEnabled = false;
#
# chart.scrollbarX = new am4core.Scrollbar();
# chart.scrollbarY = new am4core.Scrollbar();
#
# function createSeries(field, name, color) {
#   var series = chart.series.push(new am4charts.ColumnSeries());
#   series.dataFields.valueX = field;
#   series.dataFields.categoryY = "lang";
#   series.name = name;
#   series.columns.template.width = am4core.percent(95);
#   series.tooltipText = "{lang}: [b]{valueX}[/]";
#   series.strokeWidth = 1;
#   series.stroke = color;
#   series.fill = color;
#
#   // Set up tooltip
#   series.adapter.add("tooltipText", function(ev) {
#     var text = "[bold]{lang} : [/]\n";
#     chart.series.each(function(item) {
#       text += "[" + item.stroke.hex + "][/] " + item.name + ": {" + item.dataFields.valueX + "} %\n";
#     });
#     return text;
#   });
#
#   series.tooltip.getFillFromObject = false;
#   series.tooltip.background.fill = am4core.color("#fff000");
#   series.tooltip.label.fill = am4core.color("#00");
#
#   return series;
# }
#
# createSeries("pypl", "PYPL","#0000FF");
# createSeries("tiobe", "TIOBE","#4d1300");
#
# chart.legend = new am4charts.Legend();
# chart.legend.labels.template.fontSize = 12;
# chart.legend.markers.template.width = 12;
# chart.legend.markers.template.height = 12;
# chart.cursor = new am4charts.XYCursor();
# chart.cursor.behavior = "none";
# chart.cursor.lineY.disabled = true;
# chart.cursor.lineX.disabled = true;
# chart.cursor.maxTooltipDistance = 0;
#
# </script>
# </body>
# </html>

# %%
primeiro_paragrafo = soup.findAll('p')
primeiro_paragrafo
# Out:
# [<p>Python is the top programming language in TIOBE and PYPL Index. C closely follow Top-ranked Python in TIOBE.
#  In PYPL, a gap is wider as top-ranked Python has taken a lead of close to 10% from 2nd ranked Java.</p>,
#  <p><b>TIOBE:</b> Python, C, Java and C++ are way ahead of others in TIOBE Index. C++ is about to surpass Java.
#  C# and Visual Basic are very close to each other at 5th and 6th number. These four have negative
#  trends in the past five years: Java, C, C#, and PHP. PHP was at 3rd position in Mar 2010 is now at 13th.
#  Positions of Java and C have not been much affected, but their ratings are constantly declining. The rating
#  of Java has declined from 26.49% in June 2001 to 10.47% in Jun 2022.</p>,
#  <p><b>PYPL:</b> Acc to PYPL, which publishes separate ranking for five countries, Python is the top language in all five countries
#  (US, India, Germany, United Kingdom, France). Python has taken a huge lead in these five countries over the 2nd number
#  of Java, and its shares are even almost double of Java in fourFrance, United Kingdom and Germany. These two account for almost
#  half (45%) of the global search. JavaScript has attained its all time highest share of 9.5% in Sep 2021. JavaScript is at 3rd
#  position in US, India and United Kingdom and within top five in all five countries.</p>,
#  <p>PHP is the biggest loser in recent years in PYPL. Its share was over 20% in 2008; now, this fig is only 5.27% in 2022.
#  Java is too declining but not as fast as PHP. Java's contribution was over 31% in 2008, and still, it holds 18%. In
#  2004-2009, 50% of the search was of either Java or PHP.</p>,
#  <p><b>TIOBE Index:</b> TIOBE ratings are calculated by counting hits of the most popular search engines. Twenty-five
#  search engines are used to calculate the TIOBE index. The TIOBE Programming Community index is an indicator of the
#   popularity of programming languages. The index started in the year 2001 and updated once a month.</p>,
#  <p><b>PYPL Index:</b> The PYPL PopularitY of Programming Language Index is created by analyzing how often language
#   tutorials are searched on Google. The index is updated once a month.</p>]

# %%
ta_bela = soup.find('table', {'id': 'table_id1'}).find('tbody')
ta_bela
# Out:
# <tbody>
# <tr><td class="data1">1</td><td class="data1"></td><td class="name">Python</td><td class="data1"> 27.61 %</td><td class="data1">-2.8 %</td></tr>
# <tr><td class="data1">2</td><td class="data1"></td><td class="name">Java</td><td class="data1"> 17.64 %</td><td class="data1">-0.7 %</td></tr>
# <tr><td class="data1">3</td><td class="data1"></td><td class="name">JavaScript</td><td class="data1"> 9.21 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">4</td><td class="data1"></td><td class="name">C#</td><td class="data1"> 7.79 %</td><td class="data1">+0.8 %</td></tr>
# <tr><td class="data1">5</td><td class="data1"></td><td class="name">C/C++</td><td class="data1"> 7.01 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">6</td><td class="data1"></td><td class="name">PHP</td><td class="data1"> 5.27 %</td><td class="data1">-1.0 %</td></tr>
# <tr><td class="data1">7</td><td class="data1"></td><td class="name">R</td><td class="data1"> 4.26 %</td><td class="data1">+0.5 %</td></tr>
# <tr><td class="data1">8</td><td class="data1">↑↑↑</td><td class="name">TypeScript</td><td class="data1"> 2.43 %</td><td class="data1">+0.7 %</td></tr>
# <tr><td class="data1">9</td><td class="data1">↓</td><td class="name">Objective-C</td><td class="data1"> 2.21 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">10</td><td class="data1">↓</td><td class="name">Swift</td><td class="data1"> 2.17 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">11</td><td class="data1">↑↑</td><td class="name">Matlab</td><td class="data1"> 1.71 %</td><td class="data1">+0.2 %</td></tr>
# <tr><td class="data1">12</td><td class="data1">↓↓</td><td class="name">Kotlin</td><td class="data1"> 1.57 %</td><td class="data1">-0.2 %</td></tr>
# <tr><td class="data1">13</td><td class="data1">↓</td><td class="name">Go</td><td class="data1"> 1.48 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">14</td><td class="data1">↑↑</td><td class="name">Rust</td><td class="data1"> 1.29 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">15</td><td class="data1"></td><td class="name">Ruby</td><td class="data1"> 1.1 %</td><td class="data1">-0.0 %</td></tr>
# <tr><td class="data1">16</td><td class="data1">↓↓</td><td class="name">VBA</td><td class="data1"> 1.07 %</td><td class="data1">-0.2 %</td></tr>
# <tr><td class="data1">17</td><td class="data1">↑↑</td><td class="name">Ada</td><td class="data1"> 0.95 %</td><td class="data1">+0.4 %</td></tr>
# <tr><td class="data1">18</td><td class="data1">↑↑↑</td><td class="name">Scala</td><td class="data1"> 0.73 %</td><td class="data1">+0.2 %</td></tr>
# <tr><td class="data1">19</td><td class="data1">↓↓</td><td class="name">Visual Basic</td><td class="data1"> 0.65 %</td><td class="data1">-0.0 %</td></tr>
# <tr><td class="data1">20</td><td class="data1">↓↓</td><td class="name">Dart</td><td class="data1"> 0.64 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">21</td><td class="data1">↑</td><td class="name">Abap</td><td class="data1"> 0.58 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">22</td><td class="data1">↓↓</td><td class="name">Lua</td><td class="data1"> 0.51 %</td><td class="data1">-0.0 %</td></tr>
# <tr><td class="data1">23</td><td class="data1">↑</td><td class="name">Groovy</td><td class="data1"> 0.48 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">24</td><td class="data1">↓</td><td class="name">Perl</td><td class="data1"> 0.44 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">25</td><td class="data1"></td><td class="name">Julia</td><td class="data1"> 0.41 %</td><td class="data1">+0.0 %</td></tr>
# <tr><td class="data1">26</td><td class="data1"></td><td class="name">Cobol</td><td class="data1"> 0.34 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">27</td><td class="data1"></td><td class="name">Haskell</td><td class="data1"> 0.29 %</td><td class="data1">+0.1 %</td></tr>
# <tr><td class="data1">28</td><td class="data1"></td><td class="name">Delphi/Pascal</td><td class="data1"> 0.16 %</td><td class="data1">+0.1 %</td></tr>
# </tbody>

# %%
import numpy as np
linhas = ta_bela.find_all('tr')
linguagens = []
pontos = []

for linha in linhas:
    dados = linha.find_all('td')
    linguagens.append(dados[2].text)
    pontos.append(float(dados[3].text.replace(' %', '')))

print(linguagens)
print(np.sum(pontos))
# Out:
# ['Python', 'Java', 'JavaScript', 'C#', 'C/C++', 'PHP', 'R', 'TypeScript', 'Objective-C', 'Swift', 'Matlab', 'Kotlin', 'Go', 'Rust', 'Ruby', 'VBA', 'Ada', 'Scala', 'Visual Basic', 'Dart', 'Abap', 'Lua', 'Groovy', 'Perl', 'Julia', 'Cobol', 'Haskell', 'Delphi/Pascal']
# 100.0

# %%
dados = pd.DataFrame(linguagens, columns=['Linguagem'])
dados['Pontos (%)'] = pontos
dados
# Out:
#         Linguagem  Pontos
# 0          Python   27.61
# 1            Java   17.64
# 2      JavaScript    9.21
# 3              C#    7.79
# 4           C/C++    7.01
# 5             PHP    5.27
# 6               R    4.26
# 7      TypeScript    2.43
# 8     Objective-C    2.21
# 9           Swift    2.17
# 10         Matlab    1.71
# 11         Kotlin    1.57
# 12             Go    1.48
# 13           Rust    1.29
# 14           Ruby    1.10
# 15            VBA    1.07
# 16            Ada    0.95
# 17          Scala    0.73
# 18   Visual Basic    0.65
# 19           Dart    0.64
# 20           Abap    0.58
# 21            Lua    0.51
# 22         Groovy    0.48
# 23           Perl    0.44
# 24          Julia    0.41
# 25          Cobol    0.34
# 26        Haskell    0.29
# 27  Delphi/Pascal    0.16
